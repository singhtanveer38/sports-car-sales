# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv("sports_car_price.csv")
df
# Out:
#          Car Make Car Model  Year Engine Size (L) Horsepower Torque (lb-ft)  \
# 0         Porsche       911  2022               3        379            331
# 1     Lamborghini   Huracan  2021             5.2        630            443
# 2         Ferrari   488 GTB  2022             3.9        661            561
# 3            Audi        R8  2022             5.2        562            406
# 4         McLaren      720S  2021               4        710            568
# ...           ...       ...   ...             ...        ...            ...
# 1002   Koenigsegg     Jesko  2022               5       1280           1106
# 1003        Lotus     Evija  2021  Electric Motor       1972           1254
# 1004      McLaren     Senna  2021               4        789            590
# 1005       Pagani    Huayra  2021               6        764            738
# 1006        Rimac    Nevera  2021  Electric Motor       1888           1696
#
#      0-60 MPH Time (seconds) Price (in USD)
# ...

# %%
df.describe()
# Out:
#               Year
# count  1007.000000
# mean   2021.201589
# std       2.019802
# min    1965.000000
# 25%    2021.000000
# 50%    2021.000000
# 75%    2022.000000
# max    2023.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Car Make                 1007 non-null   object
#  1   Car Model                1007 non-null   object
#  2   Year                     1007 non-null   int64
#  3   Engine Size (L)          997 non-null    object
#  4   Horsepower               1007 non-null   object
#  5   Torque (lb-ft)           1004 non-null   object
#  6   0-60 MPH Time (seconds)  1007 non-null   object
#  7   Price (in USD)           1007 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 63.1+ KB

# %%
for column in df.columns:
    print(column.upper())
    print(df[column].value_counts())
    print("-"*50)
# Out:
# CAR MAKE
# Porsche          88
# McLaren          75
# Audi             71
# Lamborghini      66
# BMW              63
# Chevrolet        60
# Ferrari          55
# Mercedes-Benz    54
# Aston Martin     50
# Ford             48
# Dodge            41
# Nissan           37
# Lotus            35
# Jaguar           30
# Lexus            26
# Maserati         25
# Bentley          25
# Bugatti          23
# Tesla            19
# Alfa Romeo       16
# Acura            16
# Koenigsegg       15
# Rimac            14
# Pagani           12
# Mercedes-AMG     11
# Rolls-Royce      10
# Toyota            5
# W Motors          3
# Subaru            3
# Pininfarina       2
# TVR               2
# Kia               1
# Alpine            1
# Ariel             1
# Shelby            1
# Mazda             1
# Polestar          1
# Ultima            1
# Name: Car Make, dtype: int64
# --------------------------------------------------
# CAR MODEL
# GT                  55
# Camaro ZL1          30
# ...

# %%
df[df["0-60 MPH Time (seconds)"] == "< 1.9"]
# Out:
#     Car Make Car Model  Year Engine Size (L) Horsepower Torque (lb-ft)  \
# 364    Tesla  Roadster  2023        Electric     1,000+            737
#
#     0-60 MPH Time (seconds) Price (in USD)
# 364                   < 1.9        200,000

# %%
df.loc[df["0-60 MPH Time (seconds)"] == "< 1.9", "0-60 MPH Time (seconds)"] = "1.9"

# %%
df[df["0-60 MPH Time (seconds)"] == "1.9"]
# Out:
#         Car Make      Car Model  Year       Engine Size (L) Horsepower  \
# 99         Tesla       Roadster  2022              Electric      1000+
# 168        Rimac          C_Two  2022                   NaN       1914
# 247        Tesla  Model S Plaid  2022                   NaN       1020
# 280  Pininfarina       Battista  2022              Electric       1874
# 320        Tesla  Model S Plaid  2021              Electric       1020
# 335        Tesla       Roadster  2022                     -      1000+
# 354        Tesla       Roadster  2022              Electric      1000+
# 364        Tesla       Roadster  2023              Electric     1,000+
# 389        Tesla       Roadster  2022                   NaN     10000+
# 401        Tesla  Model S Plaid  2021  Electric (tri-motor)       1020
# 509        Rimac          C_Two  2021              Electric       1914
# 511        Tesla  Model S Plaid  2021              Electric       1020
# ...

# %%
df.columns
# Out:
# Index(['Car Make', 'Car Model', 'Year', 'Engine Size (L)', 'Horsepower',
#        'Torque (lb-ft)', '0-60 MPH Time (seconds)', 'Price (in USD)'],
#       dtype='object')

# %%
bad_cols = ['Horsepower', 'Torque (lb-ft)', 'Price (in USD)']

df[bad_cols] = df[bad_cols].astype("str")

# %%
def remove_unwanted(characters, cols):
    for character in characters:
        charCol = []
        for col in cols:
            for i in df[col]:
                if character in i:
                    charCol.append(col)
                        
        charCol = list(set(charCol))
        
        for i in charCol:
            df[i] = df[i].str.replace(character, "")

# %%
remove_unwanted(["+", ",", "-"], bad_cols)
# Out:
# /tmp/ipykernel_39533/3977965168.py:12: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[i] = df[i].str.replace(character, "")

# %%
df
# Out:
#          Car Make Car Model  Year Engine Size (L) Horsepower Torque (lb-ft)  \
# 0         Porsche       911  2022               3        379            331
# 1     Lamborghini   Huracan  2021             5.2        630            443
# 2         Ferrari   488 GTB  2022             3.9        661            561
# 3            Audi        R8  2022             5.2        562            406
# 4         McLaren      720S  2021               4        710            568
# ...           ...       ...   ...             ...        ...            ...
# 1002   Koenigsegg     Jesko  2022               5       1280           1106
# 1003        Lotus     Evija  2021  Electric Motor       1972           1254
# 1004      McLaren     Senna  2021               4        789            590
# 1005       Pagani    Huayra  2021               6        764            738
# 1006        Rimac    Nevera  2021  Electric Motor       1888           1696
#
#      0-60 MPH Time (seconds) Price (in USD)
# ...

# %%
df["Horsepower"] = df["Horsepower"].astype("int")

# %%
df["Torque (lb-ft)"] = df["Torque (lb-ft)"].replace("", np.NaN).astype("float")

# %%
df["0-60 MPH Time (seconds)"] = df["0-60 MPH Time (seconds)"].astype("float")

# %%
df["Price (in USD)"] = df["Price (in USD)"].astype("int")

# %%
df
# Out:
#          Car Make Car Model  Year Engine Size (L)  Horsepower  Torque (lb-ft)  \
# 0         Porsche       911  2022               3         379           331.0
# 1     Lamborghini   Huracan  2021             5.2         630           443.0
# 2         Ferrari   488 GTB  2022             3.9         661           561.0
# 3            Audi        R8  2022             5.2         562           406.0
# 4         McLaren      720S  2021               4         710           568.0
# ...           ...       ...   ...             ...         ...             ...
# 1002   Koenigsegg     Jesko  2022               5        1280          1106.0
# 1003        Lotus     Evija  2021  Electric Motor        1972          1254.0
# 1004      McLaren     Senna  2021               4         789           590.0
# 1005       Pagani    Huayra  2021               6         764           738.0
# 1006        Rimac    Nevera  2021  Electric Motor        1888          1696.0
#
# ...

# %%
df.describe()
# Out:
#               Year    Horsepower  Torque (lb-ft)  0-60 MPH Time (seconds)  \
# count  1007.000000   1007.000000     1003.000000              1007.000000
# mean   2021.201589    657.984111      559.570289                 3.513406
# std       2.019802    593.017842      441.380051                 0.777639
# min    1965.000000    181.000000        0.000000                 1.800000
# 25%    2021.000000    454.000000      406.000000                 2.900000
# 50%    2021.000000    591.000000      509.000000                 3.500000
# 75%    2022.000000    708.500000      604.000000                 4.000000
# max    2023.000000  10000.000000    10000.000000                 6.500000
#
#        Price (in USD)
# count    1.007000e+03
# mean     3.820359e+05
# std      7.383227e+05
# min      2.500000e+04
# 25%      7.180000e+04
# 50%      1.400000e+05
# 75%      2.500000e+05
# max      5.200000e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Car Make                 1007 non-null   object
#  1   Car Model                1007 non-null   object
#  2   Year                     1007 non-null   int64
#  3   Engine Size (L)          997 non-null    object
#  4   Horsepower               1007 non-null   int64
#  5   Torque (lb-ft)           1003 non-null   float64
#  6   0-60 MPH Time (seconds)  1007 non-null   float64
#  7   Price (in USD)           1007 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 63.1+ KB

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 994 entries, 0 to 1006
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Car Make                 994 non-null    object
#  1   Car Model                994 non-null    object
#  2   Year                     994 non-null    int64
#  3   Engine Size (L)          994 non-null    object
#  4   Horsepower               994 non-null    int64
#  5   Torque (lb-ft)           994 non-null    float64
#  6   0-60 MPH Time (seconds)  994 non-null    float64
#  7   Price (in USD)           994 non-null    int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 69.9+ KB

# %%
df.to_parquet("sport_car_price.parquet", index=None)

# %%
expensive = df.copy()

# %%
expensive = expensive.sort_values("Price (in USD)", ascending=False)
expensive
# Out:
#         Car Make                Car Model  Year Engine Size (L)  Horsepower  \
# 541      Bugatti  Chiron Super Sport 300+  2022               8        1578
# 823      Bugatti  Chiron Super Sport 300+  2021               8        1578
# 983      Bugatti                   Chiron  2022               8        1500
# 438  Lamborghini                     Sián  2021             6.5         819
# 624      Bugatti         Chiron Pur Sport  2021               8        1500
# ..           ...                      ...   ...             ...         ...
# 92         Mazda               MX-5 Miata  2021               2         181
# 924    Chevrolet                   Camaro  2021             6.2         455
# 997    Chevrolet                   Camaro  2021             6.2         455
# 597    Chevrolet                   Camaro  2021             6.2         455
# 886    Chevrolet                   Camaro  2022             6.2         455
#
# ...

# %%
plt.bar(x=expensive["Car Model"][:6], height=expensive["Price (in USD)"][:6])
plt.figure(figsize=(16,9))
# Out:
# /tmp/ipykernel_39533/1041555945.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.bar(x=expensive["Car Model"][:6], height=expensive["Price (in USD)"][:6])
